# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\kumar g\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\kumar g\anaconda3\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\kumar g\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\kumar g\anaconda3\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\kumar g\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\kumar g\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
corpus="""Hello Welcome,to RGUKT RKVALLEY.
Hope everything gives us is lot of happiness of tears.
"""

# %%
print(corpus)
# Out:
# Hello Welcome,to RGUKT RKVALLEY.
# Hope everything gives us is lot of happiness of tears.

# %%
##  Tokenization
## Sentence-->paragraphs
from nltk.tokenize import sent_tokenize

# %%
documents=sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome,to RGUKT RKVALLEY.
# Hope everything gives us is lot of happiness of tears.

# %%
## Tokenization 
## Paragraph-->words
## sentence--->words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'RGUKT',
#  'RKVALLEY',
#  '.',
#  'Hope',
#  'everything',
#  'gives',
#  'us',
#  'is',
#  'lot',
#  'of',
#  'happiness',
#  'of',
#  'tears',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'RGUKT', 'RKVALLEY', '.']
# ['Hope', 'everything', 'gives', 'us', 'is', 'lot', 'of', 'happiness', 'of', 'tears', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'RGUKT',
#  'RKVALLEY',
#  '.',
#  'Hope',
#  'everything',
#  'gives',
#  'us',
#  'is',
#  'lot',
#  'of',
#  'happiness',
#  'of',
#  'tears',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'RGUKT',
#  'RKVALLEY.',
#  'Hope',
#  'everything',
#  'gives',
#  'us',
#  'is',
#  'lot',
#  'of',
#  'happiness',
#  'of',
#  'tears',
#  '.']
